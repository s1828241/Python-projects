# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r'C:\Users\s1828241\Documents\Python projects\homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline 
plt.xlabel('area (sqr ft)')
plt.ylabel('price (US$)')
plt.scatter(df.area, df.price, color = 'red', marker = '+')

# %%
reg = linear_model.LinearRegression(n_jobs = 1)
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression(n_jobs=1)

# %%
reg.predict([[3300]])
# Out:
# C:\Users\s1828241\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
print("The gradient is", reg.coef_)
print("The y-intercept is", reg.intercept_)
# Out:
# The gradient is [135.78767123]
# The y-intercept is 180616.43835616432

# %%
def CostPrediction(x):
    return reg.coef_*x + reg.intercept_

CostPrediction(5000)
# Out:
# array([859554.79452055])

# %%
# %matplotlib inline 
plt.xlabel('area (sqr ft)')
plt.ylabel('price (US$)')
plt.scatter(df.area, df.price, color = 'red', marker = '+')
plt.plot(df.area, reg.predict(df[['area']]), color = 'blue')

# %%
d = pd.read_csv("areas.csv")
d.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p = reg.predict(d)

# %%
d['prices'] = p
d.to_csv("prediction.csv", index = False)

# %% [markdown]
# Let us now, for an exercise, predict the 2020 Canadian per capita income based off of a data frame up to and including 2018.

# %%
df_PCI = pd.read_csv('canada_per_capita_income.csv')
reg_PCI = linear_model.LinearRegression(n_jobs = 1)
reg_PCI.fit(df_PCI[['year']], df_PCI.pci)
# Out:
# LinearRegression(n_jobs=1)

# %%
reg_PCI.predict([[2020]])
# Out:
# C:\Users\s1828241\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %% [markdown]
# The actual per capita income in 2020 was $43,258.26, slightly more than predicted.
